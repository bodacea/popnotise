# %% [markdown]
# # Explore datasets from digi (Jonathan Albright)
#
# NB data comes in zipfiles: have chosen to unzip them here rather than in the data directory (see https://pymotw.com/2/zipfile/). Oh fkit - have unzipped them because junk and pdfs.  For posterity, zipcode was:
#
# import zipfile
# zf = zipfile.ZipFile('../drivedatasets/digi/d1gi-missing-fb-posts-w-share-stats.zip')
# print(zf.namelist())

# %%
import pandas as pd

datadir = '../drivedatasets/digi/d1gi-missing-fb-posts-w-share-stats/data'
df = pd.read_csv('{}/{}.csv'.format(datadir, 'blacktivist'))
df.sort_values('date')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-6249dc4f3b78> in <module>()
#       2
#       3 datadir = '../drivedatasets/digi/d1gi-missing-fb-posts-w-share-stats/data'
# ----> 4 df = pd.read_csv('{}/{}.csv'.format(datadir, 'blacktivist'))
#       5 df.sort_values('date')
#
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
#df[['followers', 'date']].plot()
plt.scatter(df['date'], df['followers'])

# %%
df[['date', 'followers']].sort_values('date').plot()
