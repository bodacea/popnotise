# %% [markdown]
# # cluster congress tweets

# %%
import pandas as pd
import math
import datetime
pd.set_option("display.max_rows", 3000)
pd.set_option('max_colwidth',400)

datadir = '../drivedatasets/nbc_congress_trolls/'

# %% [markdown]
# ## Look at tweet contents

# %%
dfregtweets = pd.read_csv('{}/regular_reader_tweets.csv'.format(datadir))
dfregtweets
# Out:
#                user_key       created_str  \
# 0         ryanmaxwell_1   3/22/2016 18:31
# 1       detroitdailynew  10/10/2016 20:57
# 2            cookncooks   2/22/2017 12:43
# 3          queenofthewo  12/26/2016 15:06
# 4          mrclydepratt     8/6/2017 2:36
# 5           giselleevns  10/26/2016 15:33
# 6             baobaeham    3/7/2017 18:11
# 7        judelambertusa  12/30/2016 12:49
# 8         ameliebaldwin   10/30/2016 1:48
# 9             hiimkhloe   3/16/2016 19:07
# 10           jasper_fly   1/11/2017 15:46
# 11         patriotblake  12/12/2016 11:43
# 12       anthonywoodboy   6/10/2015 20:33
# 13       pamela_moore13    8/31/2016 1:49
# 14          laurabaeley    1/23/2017 8:59
# 15          giselleevns    1/4/2017 15:32
# 16       pamela_moore13   9/19/2016 23:11
# 17        brianaregland   1/11/2017 10:36
# 18       patriotraphael    7/13/2015 1:57
# 19              hyddrox    2/9/2017 10:26
# 20      kansasdailynews   7/27/2016 14:55
# ...

# %%
dfregtweets['user_key'].value_counts()
# Out:
# ameliebaldwin      9269
# hyddrox            6813
# giselleevns        6652
# patriotblake       4140
# thefoundingson     3663
# melvinsroberts     3346
# mrclydepratt       3263
# brianaregland      3261
# leroylovesusa      3229
# baobaeham          3215
# melanymelanin      3212
# laurabaeley        3201
# jeffreykahunas     3197
# datwisenigga       3197
# ten_gop            3194
# emileewaren        3192
# garrettsimpson_    3188
# jacquelinisbest    3169
# _nickluna_         3159
# michellearry       3156
# willisbonnerr      3156
# cookncooks         3143
# dorothiebell       3142
# paulinett          3057
# notritahart        3028
# mr_clampin         3010
# cassieweltch       3009
# traceyhappymom     2990
# queenofthewo       2988
# kathiemrr          2968
# jasper_fly         2966
# daileyjadon        2956
# heyits_toby        2909
# lazykstafford      2906
# puredavie          2786
# evagreen69         2733
# judelambertusa     2640
# hiimkhloe          2618
# ...

# %% [markdown]
# ## Look at tweet details
#
# Experiment: see if users change their handles at all
# * Tried usersbypop = dftweets[['user_id', 'user_key']].drop_duplicates().groupby('user_id').count().sort_values('user_key', ascending=False)
# * usersbypop counts were all '1'.
# * So no handle changes seen at the top of the dataset - there wasn't an obvious change to play with, but this doesn't mean that we looked at enough of the dataset to see changes though.

# %%
dftweets = pd.read_csv('{}tweets.csv'.format(datadir), nrows=2000)
dftweets
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
dftweets.head()
# Out:
#         user_id         user_key     created_at          created_str  \
# 0  2.532612e+09        kathiemrr  1488207240000  2017-02-27 14:54:00
# 1  2.531160e+09   traceyhappymom  1471272620000  2016-08-15 14:50:20
# 2           NaN    evewebster373  1435701369000  2015-06-30 21:56:09
# 3  4.840552e+09      blacktolive  1474013088000  2016-09-16 08:04:48
# 4  1.694026e+09  jacquelinisbest  1474227985000  2016-09-18 19:46:25
#
#    retweet_count retweeted  favorite_count  \
# 0            NaN       NaN             NaN
# 1            NaN       NaN             NaN
# 2            NaN       NaN             NaN
# 3           18.0     False            17.0
# 4            0.0     False             0.0
#
#                                                                                                                                               text  \
# ...

# %%
dftweets['hashtags'].value_counts()
# Out:
# []                                                                                                                                                                                               1150
# ["Politics"]                                                                                                                                                                                       27
# ["news"]                                                                                                                                                                                           13
# ["MerkelMussBleiben"]                                                                                                                                                                               9
# ["IHaveARightToKnow"]                                                                                                                                                                               8
# ...

# %%
dftweets[dftweets['hashtags'].str.contains('tcot')]
# Out:
#            user_id         user_key     created_at          created_str  \
# 604   2.572058e+09    leroylovesusa  1476142893000  2016-10-10 23:41:33
# 786   1.620474e+09     ramonasnails  1478326887000  2016-11-05 06:21:27
# 804   1.671235e+09          hyddrox  1475787394000  2016-10-06 20:56:34
# 893   1.685718e+09       j0hnlarsen  1471515604000  2016-08-18 10:20:04
# 907   1.629828e+09       cassishere  1474205654000  2016-09-18 13:34:14
# 1001  2.606302e+09       finley1589  1470220567000  2016-08-03 10:36:07
# 1218  1.660771e+09  garrettsimpson_  1477382599000  2016-10-25 08:03:19
# 1273  1.669575e+09          deusxyx  1471515558000  2016-08-18 10:19:18
# 1277  1.662779e+09        rh0lbr00k  1474299729000  2016-09-19 15:42:09
# 1363  2.540882e+09      heyits_toby  1488246856000  2017-02-28 01:54:16
# 1379           NaN    _billy_moyer_  1454937425000  2016-02-08 13:17:05
# 1443  1.679279e+09    ameliebaldwin  1476968065000  2016-10-20 12:54:25
# ...
